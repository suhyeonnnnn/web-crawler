# %%
import json 
import requests 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pickle
import datetime as dt
from tqdm.notebook import tqdm
from IPython.display import Image

# %%
pd.set_option('max_columns', 100) # To see 50 columns
pd.set_option('max_rows', 100) # To see 100 rows

# %%
api = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJYLUFwcC1SYXRlLUxpbWl0IjoiNTAwOjEwIiwiYWNjb3VudF9pZCI6IjE1MTAyMjA3NzUiLCJhdXRoX2lkIjoiMiIsImV4cCI6MTY3NzQwMTAwNCwiaWF0IjoxNjYxODQ5MDA0LCJuYmYiOjE2NjE4NDkwMDQsInNlcnZpY2VfaWQiOiI0MzAwMTE0ODEiLCJ0b2tlbl90eXBlIjoiQWNjZXNzVG9rZW4ifQ.ngxIAncZ_jyxdeoYK12MPUkl_7SU7U7mEAyysZ7IC_k'

# %%
headers = {'Authorization': api}

# %%
total=[]
for i in tqdm(range(68660,1000000)):
    match = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches?matchtype=50&offset={i*100}&limit=100&orderby=desc',headers=headers, timeout=5)
    match=match.json()
    match=pd.DataFrame(match)
    total.append(match)
        
result=pd.concat(total, ignore_index=True)
# Out:
#   0%|          | 0/931340 [00:00<?, ?it/s]

# %%
result=pd.concat(total, ignore_index=True)
result
# Out:
#                                 0
# 0        630fbda703e986834d491e25
# 1        630fbd9b392b8e57e77a47e2
# 2        630fbc541c290ff528e79419
# 3        630fbc1bcdd434877a167fa4
# 4        630fbbf2a2425c725cc5c1b7
# ...                           ...
# 3398371  63090436f55d437ea6405362
# 3398372  63090436dd142b2cb816584a
# 3398373  63090436c79b5a2c28a59170
# 3398374  63090436b9104b1eddf006aa
# 3398375  630904369c7dc698f7b300b8
#
# [3398376 rows x 1 columns]

# %%
match_url='https://api.nexon.co.kr/fifaonline4/v1.0/matches/{}'
match_urls=[]
for i in tqdm(result[0]): # total아니라 result[0]으로 하셔야해용
    
    match_urls.append(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{i}'.format(i)) #여기서 total이 아니라 i 쓰셔야해요!

match_urls=pd.DataFrame(match_urls)
match_urls
# Out:
#   0%|          | 0/3398376 [00:00<?, ?it/s]
#                                                          0
# 0        https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1        https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 2        https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3        https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 4        https://api.nexon.co.kr/fifaonline4/v1.0/match...
# ...                                                    ...
# 3398371  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398372  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398373  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398374  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398375  https://api.nexon.co.kr/fifaonline4/v1.0/match...
#
# [3398376 rows x 1 columns]

# %%
df_yu = match_urls.loc[1699189:]
df_sh = match_urls.loc[:1699188]

# %%
df_yu.to_csv('match_urls_yu.csv')
df_sh.to_csv('match_urls_sh.csv')

# %%
match_urls.to_csv("match_urls.csv", index = False)

# %%
df_sh = pd.read_csv("match_urls_sh.csv")
df_sh
# Out:
#          Unnamed: 0                                                  0
# 0                 0  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1                 1  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 2                 2  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3                 3  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 4                 4  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# ...             ...                                                ...
# 1699184     1699184  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1699185     1699185  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1699186     1699186  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1699187     1699187  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 1699188     1699188  https://api.nexon.co.kr/fifaonline4/v1.0/match...
#
# [1699189 rows x 2 columns]

# %%
match_urls = df_sh.drop('Unnamed: 0', axis =1)

# %%
match_urls['0'][1]
# Out:
# 'https://api.nexon.co.kr/fifaonline4/v1.0/matches/630fbd9b392b8e57e77a47e2'

# %%
match_urls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1699189 entries, 0 to 1699188
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   0       object
# dtypes: object(1)
# memory usage: 13.0+ MB

# %%
r3 = []
i = 0

pbar = tqdm(desc='while loop',total = 1000000000)
while i <1000000000:
    j = match_urls[0][i]
    r= requests.get(j,headers=headers)
    r2=r.json()
    r3.append(r2)
    i += 1000
    pbar.update(i)
        
print('Loop completed')
pbar.close()
# Out:
# while loop:   0%|          | 0/1000000000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
r3=pd.DataFrame(r3)
r3
# Out:
#                      matchId            matchDate  matchType  \
# 0   630fbda703e986834d491e25  2022-09-01T04:59:47         50
# 1   630fb8e679b7959423e98e40  2022-09-01T04:48:58         50
# 2   630fb6740bdaf8038c62fccd  2022-09-01T04:39:04         50
# 3   630fb41f166e9ca9b76d26d4  2022-09-01T04:29:02         50
# 4   630fb1ca371c605497c5fe72  2022-09-01T04:20:53         50
# 5   630fafb6a55dfd4cac79d9f5  2022-09-01T04:11:17         50
# 6   630fada11ec3e5dab13ace60  2022-09-01T04:01:18         50
# 7   630fabdb985125928cabcaa8  2022-09-01T03:53:42         50
# 8   630faa1ce88dfba3f99f2289  2022-09-01T03:47:05         50
# 9   630fa89308bf323d013a8224  2022-09-01T03:39:56         50
# 10  630fa72156127e774bb05241  2022-09-01T03:34:58         50
# 11  630fa5b62cbc6751ba89f782  2022-09-01T03:27:57         50
# 12  630fa457b220c85dae2129ad  2022-09-01T03:21:25         50
#
#                                             matchInfo
# 0   [{'accessId': '6f4b6c8ead903427e660c6b0', 'nic...
# ...

# %%
# 한번 내보내기
r3.to_csv("api_sample.csv",index = False)

# %%
print(i)
# Out:
# 13000

# %%
# 자르고 계속
match_urls2 = match_urls.loc[14000:]
match_urls2
# Out:
#                                                          0
# 14000    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 14001    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 14002    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 14003    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 14004    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# ...                                                    ...
# 3398371  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398372  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398373  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398374  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398375  https://api.nexon.co.kr/fifaonline4/v1.0/match...
#
# [3384376 rows x 1 columns]

# %%
r3 = []
i = 0

pbar = tqdm(desc='while loop',total = 1000000000)
while i <1000000000:
    j = match_urls[0][i]
    r= requests.get(j,headers=headers)
    r2=r.json()
    r3.append(r2)
    i += 1000
    pbar.update(i)
        
print('Loop completed')
pbar.close()
# Out:
#   0%|          | 0/3365380 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
# ...

# %%
r3=pd.DataFrame(r3)
r3
# Out:
#                         matchId            matchDate  matchType  \
# 0      630f902bdaa4ab457d80d526  2022-09-01T02:01:54         50
# 1      630f8ffee3bc6523b853c125  2022-09-01T02:00:13         50
# 2      630f8fe2ce134c543bb65992  2022-09-01T02:00:46         50
# 3      630f8f6d7199900902a1d249  2022-09-01T02:01:00         50
# 4      630f851d00e8d130df4a7272  2022-09-01T00:59:31         50
# ...                         ...                  ...        ...
# 95417  630f6a41b464844a526ce6f6  2022-08-31T23:12:09         50
# 95418  630f6a41ae6dd7562cb5905a  2022-08-31T23:15:40         50
# 95419  630f6a41a0a6ec825a0101a3  2022-08-31T23:14:49         50
# 95420  630f6a4171d70963291886a0  2022-08-31T23:13:46         50
# 95421  630f6a41610aed3b69870d01  2022-08-31T23:19:05         50
#
#                                                matchInfo
# 0      [{'accessId': '38f89da916b3455445b303e9', 'nic...
# 1      [{'accessId': '8ddd8a2e773ba58810d85038', 'nic...
# ...

# %%
r3.to_csv("api_sample2.csv",index = False)

# %%
print(i)

# %%
# 자르고 계속
match_urls3 = match_urls2.loc[I+1000:]
match_urls3
# Out:
#                                                          0
# 95422    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 95423    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 95424    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 95425    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 95426    https://api.nexon.co.kr/fifaonline4/v1.0/match...
# ...                                                    ...
# 3398371  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398372  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398373  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398374  https://api.nexon.co.kr/fifaonline4/v1.0/match...
# 3398375  https://api.nexon.co.kr/fifaonline4/v1.0/match...
#
# [3302954 rows x 1 columns]

# %%
api = pd.read_csv("api_sample2.csv")
api
# Out:
#                         matchId            matchDate  matchType  \
# 0      630f902bdaa4ab457d80d526  2022-09-01T02:01:54         50
# 1      630f8ffee3bc6523b853c125  2022-09-01T02:00:13         50
# 2      630f8fe2ce134c543bb65992  2022-09-01T02:00:46         50
# 3      630f8f6d7199900902a1d249  2022-09-01T02:01:00         50
# 4      630f851d00e8d130df4a7272  2022-09-01T00:59:31         50
# ...                         ...                  ...        ...
# 95417  630f6a41b464844a526ce6f6  2022-08-31T23:12:09         50
# 95418  630f6a41ae6dd7562cb5905a  2022-08-31T23:15:40         50
# 95419  630f6a41a0a6ec825a0101a3  2022-08-31T23:14:49         50
# 95420  630f6a4171d70963291886a0  2022-08-31T23:13:46         50
# 95421  630f6a41610aed3b69870d01  2022-08-31T23:19:05         50
#
#                                                matchInfo
# 0      [{'accessId': '38f89da916b3455445b303e9', 'nic...
# 1      [{'accessId': '8ddd8a2e773ba58810d85038', 'nic...
# ...

# %%
api.loc[60000:]
# Out:
#                         matchId            matchDate  matchType  \
# 60000  630f75bcc841fe88d3e4545a  2022-09-01T00:02:31         50
# 60001  630f75bcb89d0194af1203a3  2022-09-01T00:03:53         50
# 60002  630f75bca2f07a4dd4f9a7cc  2022-09-01T00:05:26         50
# 60003  630f75bc9c51fd02d71476bf  2022-09-01T00:03:08         50
# 60004  630f75bc9611f941d18b6e06  2022-09-01T00:04:12         50
# ...                         ...                  ...        ...
# 95417  630f6a41b464844a526ce6f6  2022-08-31T23:12:09         50
# 95418  630f6a41ae6dd7562cb5905a  2022-08-31T23:15:40         50
# 95419  630f6a41a0a6ec825a0101a3  2022-08-31T23:14:49         50
# 95420  630f6a4171d70963291886a0  2022-08-31T23:13:46         50
# 95421  630f6a41610aed3b69870d01  2022-08-31T23:19:05         50
#
#                                                matchInfo
# 60000  [{'accessId': '54588176cd5487d16b44d27e', 'nic...
# 60001  [{'accessId': '044269b45cc5fccff7536ac5', 'nic...
# ...

# %%
8/31 밤 11시 ~ 9월 1일 오전 2시
